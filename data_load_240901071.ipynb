# %% [markdown]
# <a href="https://colab.research.google.com/github/nivetha-240901071/python-programing-using-machine-learning/blob/main/data_load_240901071.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
d=pd.read_csv("emp details.csv")
print(d.head)
# Out:
# <bound method NDFrame.head of     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
df=pd.DataFrame(d)
print("columns",df.columns)
# Out:
# columns Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (100, 11)

# %%
print("First Name",df['First Name'])
# Out:
# First Name 0         Lois
# 1       Brenda
# 2          Joe
# 3        Diane
# 4     Benjamin
#         ...
# 95        Jose
# 96      Harold
# 97      Nicole
# 98     Theresa
# 99       Tammy
# Name: First Name, Length: 100, dtype: object

# %%
print("Name prefix",df['Name Prefix'])
# Out:
# Name prefix 0     Drs.
# 1      Ms.
# 2      Dr.
# 3     Drs.
# 4      Mr.
#       ...
# 95     Mr.
# 96     Dr.
# 97     Ms.
# 98    Mrs.
# 99    Drs.
# Name: Name Prefix, Length: 100, dtype: object

# %%
print("particular row",df.loc[10])
# Out:
# particular row Emp ID                                  231469
# Name Prefix                                Mr.
# First Name                               Ralph
# Middle Initial                               L
# Last Name                               Flores
# Gender                                       M
# E Mail                  ralph.flores@yahoo.com
# Father's Name                     Terry Flores
# Mother's Name                  Michelle Flores
# Mother's Maiden Name                     Moore
# Salary                                  118457
# Name: 10, dtype: object

# %%
print(df['Salary'] == 168251)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Salary, Length: 100, dtype: bool

# %%
d=df['Salary']/5
print(d.head())
# Out:
# 0    33650.2
# 1    10212.6
# 2    10031.0
# 3    36058.8
# 4    23528.4
# Name: Salary, dtype: float64
