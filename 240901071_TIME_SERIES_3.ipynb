# %% [markdown]
# <a href="https://colab.research.google.com/github/nivetha-240901071/python-programing-using-machine-learning/blob/main/240901071_TIME_SERIES_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02    0.802061
# 2011-01-05   -2.523990
# 2011-01-07    0.522958
# 2011-01-08   -0.762750
# 2011-01-10   -0.111515
# 2011-01-12    0.975678
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01   -0.801454
# 2000-01-02    0.548345
# 2000-01-03    0.611022
# 2000-01-04   -0.499569
# 2000-01-05    1.742853
#                 ...
# 2002-09-22    1.054867
# 2002-09-23   -0.515269
# 2002-09-24    0.300999
# 2002-09-25    0.570184
# 2002-09-26   -0.658731
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01   -0.542398
# 2001-01-02   -1.231190
# 2001-01-03   -0.368486
# 2001-01-04   -0.071689
# 2001-01-05   -0.558247
#                 ...
# 2001-12-27   -2.402723
# 2001-12-28   -1.377026
# 2001-12-29   -0.929402
# 2001-12-30   -0.779542
# 2001-12-31    0.836522
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-05 month 2001 year:\n", longer_ts["2001-05"])
# Out:
# Date range-05 month 2001 year:
#  2001-05-01    0.802184
# 2001-05-02   -0.504346
# 2001-05-03    0.516228
# 2001-05-04   -0.075265
# 2001-05-05   -0.054584
# 2001-05-06    1.450617
# 2001-05-07   -0.133623
# 2001-05-08   -0.200204
# 2001-05-09    1.135124
# 2001-05-10   -0.707695
# 2001-05-11    2.268374
# 2001-05-12    1.482892
# 2001-05-13    0.559195
# 2001-05-14   -0.339475
# 2001-05-15    1.514814
# 2001-05-16    1.252693
# 2001-05-17    0.472569
# 2001-05-18   -0.496444
# 2001-05-19    0.856549
# 2001-05-20   -0.940300
# 2001-05-21    0.632890
# 2001-05-22   -0.229470
# 2001-05-23    0.815243
# 2001-05-24   -1.312282
# 2001-05-25   -0.486722
# 2001-05-26   -3.116981
# 2001-05-27    0.192611
# 2001-05-28    0.645952
# 2001-05-29   -0.137387
# 2001-05-30    0.892489
# 2001-05-31    1.049432
# Freq: D, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01   -0.801454
# 2000-01-02    0.548345
# 2000-01-03    0.611022
# 2000-01-04   -0.499569
# 2000-01-05    1.742853
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01    1.030106
# 2000-02-02    0.245171
# 2000-02-03    0.227865
# 2000-02-04    1.744322
# 2000-02-05   -0.052366
# 2000-02-06   -2.300114
# 2000-02-07   -0.720671
# 2000-02-08   -1.008636
# 2000-02-09   -0.073402
# 2000-02-10    0.221586
# 2000-02-11    0.627273
# 2000-02-12    0.363177
# 2000-02-13   -0.369745
# 2000-02-14    1.381536
# 2000-02-15    0.395737
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26    0.450069
# 2000-09-27   -0.749693
# 2000-09-28   -0.635832
# 2000-09-29   -0.068703
# 2000-09-30    0.639668
#                 ...
# 2002-09-22    1.054867
# 2002-09-23   -0.515269
# 2002-09-24    0.300999
# 2002-09-25    0.570184
# 2002-09-26   -0.658731
# Freq: D, Length: 731, dtype: float64

# %%
print("\nDate range from 26-9-2001 to 25-9-2002:\n",longer_ts[datetime(2001,9,26):datetime(2002,9,25)])
# Out:
# Date range from 26-9-2001 to 25-9-2002:
#  2001-09-26   -0.666046
# 2001-09-27    0.258596
# 2001-09-28   -1.151679
# 2001-09-29   -0.534391
# 2001-09-30    0.756783
#                 ...
# 2002-09-21    0.110049
# 2002-09-22    1.054867
# 2002-09-23   -0.515269
# 2002-09-24    0.300999
# 2002-09-25    0.570184
# Freq: D, Length: 365, dtype: float64
