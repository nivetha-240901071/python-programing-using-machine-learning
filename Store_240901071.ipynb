# %% [markdown]
# <a href="https://colab.research.google.com/github/nivetha-240901071/python-programing-using-machine-learning/blob/main/Store_240901071.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],
index=['one','two','three'],

columns=['a','b','c'])
print(df)
# Out:
#        a  b  c
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %%
print("Taking the input from Dataframe and storing in the Excel file")
df.to_excel('Pandas_to_excel.xlsx',sheet_name='new_sheet_name')
# Out:
# Taking the input from Dataframe and storing in the Excel file

# %%
d=pd.DataFrame([[110,210,310],[12,220,320],[310,320,330]],index=['four','five','six'],columns=['a','b','c'])
d.to_excel('Pandas_to_excel1.xlsx',sheet_name='new_sheet_name')

# %%
x=pd.read_excel('Pandas_to_excel.xlsx')
y=pd.read_excel('Pandas_to_excel1.xlsx')
z=pd.concat([x,y])
z.to_excel('pandas_to_excel3.xlsx')

# %%
df=z.sort_values(["a"])
print(df)
df.to_excel('pandas_to_excel4.xlsx')
# Out:
#   Unnamed: 0    a    b    c
# 0        one    1    2    3
# 1        two    4    5    6
# 2      three    7    8    9
# 1       five   12  220  320
# 0       four  110  210  310
# 2        six  310  320  330

# %%
df=pd.read_excel('pandas_to_excel4.xlsx')
print(df)
print(list(df))
print(format(len(df)))
# Out:
#    Unnamed: 0.1 Unnamed: 0    a    b    c
# 0             0        one    1    2    3
# 1             1        two    4    5    6
# 2             2      three    7    8    9
# 3             1       five   12  220  320
# 4             0       four  110  210  310
# 5             2        six  310  320  330
# ['Unnamed: 0.1', 'Unnamed: 0', 'a', 'b', 'c']
# 6
