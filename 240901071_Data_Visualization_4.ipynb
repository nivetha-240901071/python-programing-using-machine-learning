# %% [markdown]
# <a href="https://colab.research.google.com/github/nivetha-240901071/python-programing-using-machine-learning/blob/main/240901071_Data_Visualization_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

#seaborn package
Xpoints=np.array([0,20,120,200])
Ypoints=np.array([10,80,100,120,150,180,250])

# %%
sns.scatterplot(data=Ypoints)
plt.show()

# %%
sns.barplot(data=Ypoints)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

#3-D plot
X=np.array([1,2,6,8,12,14,20])
Y=np.array([3,8,1,10,12,16,18])
Z=np.array([5,10,15,20,25,30,35]) # Added Z array for 3D plot
Fig=plt.figure(figsize=(12,8))
Ax=plt.axes(projection='3d') # Corrected 'prohection' to 'projection'
Plt_3d=Ax.scatter3D(X,Y,Z) # Changed 'ax' to 'Ax', 'x' to 'X', 'y' to 'Y', added Z
Fig.colorbar(Plt_3d) # Changed 'Plt' to 'Fig' for colorbar
plt.show()

#plotly package
X_plotly=np.array([10,80,100,120,150,180,250]) # Renamed X to X_plotly to avoid confusion

fig=px.scatter(x=X_plotly) # Changed 'x' to 'X_plotly'
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
