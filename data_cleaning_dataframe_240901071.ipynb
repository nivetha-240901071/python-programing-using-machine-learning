# %% [markdown]
# <a href="https://colab.research.google.com/github/nivetha-240901071/python-programing-using-machine-learning/blob/main/data_cleaning_dataframe_240901071.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("original Dataframe with NaN\n",df)
print("\n")
print("dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# original Dataframe with NaN
#          one       two     three
# a  0.734324  2.841651  0.557048
# b       NaN       NaN       NaN
# c -0.126330  1.418846  0.171686
# d -1.019682 -0.783322  0.607781
# e       NaN       NaN       NaN
# f  0.554778  0.914767  1.175952
#
#
# dropped DataFrame
#          one       two     three
# a  0.734324  2.841651  0.557048
# c -0.126330  1.418846  0.171686
# d -1.019682 -0.783322  0.607781
# f  0.554778  0.914767  1.175952

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.016116 -1.329252  0.835789
# b       NaN       NaN       NaN
# c  0.305067  1.122491  0.269086
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.016116 -1.329252  0.835789
# b  0.000000  0.000000  0.000000
# c  0.305067  1.122491  0.269086

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -0.642002  0.032440 -0.495502
# b       NaN       NaN       NaN
# c  1.078111 -0.942699 -0.076958
# d  0.199524  1.027515  0.005612
# e       NaN       NaN       NaN
# f  1.889538  0.369985 -0.657855
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.693640 -1.160709 -1.409081
# b       NaN       NaN       NaN
# c -0.221620 -2.414805  1.177432
# d -1.407279 -0.965829  0.026615
# e       NaN       NaN       NaN
# f -1.966615 -0.316092  1.493017
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.693640 -1.160709 -1.409081
# b -0.221620 -2.414805  1.177432
# c -0.221620 -2.414805  1.177432
# d -1.407279 -0.965829  0.026615
# e -1.966615 -0.316092  1.493017
# f -1.966615 -0.316092  1.493017
# /tmp/ipykernel_443/4216389697.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
